# %%
import random

def making_a_guess():
    x = 0
    global update_display
    correct_guess = False
    for letter in chosen_word:
        if guess.lower() == chosen_word[x]:
            blank_list[x] = guess.lower()
            correct_guess = True
        x += 1
    if correct_guess == False:
        print(f"There is no {guess}, sorry.")
        update_display += 1
    x = 0


HANGMANPICS = ['''
  +---+
  |   |
      |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========''']

word_list = ["sri", "indu", "college", "btech", "pooja", "america", "us", "students"]

chosen_word = list(random.choice(word_list))

blank = ""
for letter in chosen_word:
    blank += "_"
blank_list = list(blank)

update_display = 0

#----------------------------------------------------------------------------------------------

print(HANGMANPICS[update_display])
guess = input(f"Welcome to hangman.\n{blank}\nMake a guess? ")
making_a_guess()
print(HANGMANPICS[update_display])
print(''.join(blank_list))
while update_display < 6:
    if blank_list == chosen_word:
        print("YOU WIN!")
        break
    guess = input("Make another guess? ")
    making_a_guess()
    print(HANGMANPICS[update_display])
    print(''.join(blank_list))
if update_display == 6:
    print("GAME OVER.")
# Out:
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
# Welcome to hangman.
# ____
# Make a guess? s
# There is no s, sorry.
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# ____
# Make another guess? u
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# ___u
# Make another guess? t
# There is no t, sorry.
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# ___u
# Make another guess? p
# There is no p, sorry.
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# ___u
# Make another guess? s
# There is no s, sorry.
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
# ___u
# Make another guess? p
# There is no p, sorry.
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
# ___u
# Make another guess? o
# There is no o, sorry.
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# =========
# ___u
# GAME OVER.
